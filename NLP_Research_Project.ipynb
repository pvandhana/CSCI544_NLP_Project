# %%
import pandas as pd
import requests
import json

# youtube api key: AIzaSyBMk7tRDPZYTBDwqvtzcF4E6ciQS-Rxtr8 0-4900
# key 2: AIzaSyARHge-NUDpfRYr2-gz1tqYGvgcUJhxm8c 4901 - 9801
# key 3: AIzaSyDrCS-EG9LXEvraEaHfOSl2QrNJ51SrwcE 9802 - 14702
# key 4: AIzaSyAsGZty7w_7cwXtky6YQrGlM-B3TOsRqJ4 14703 - 19603
# key 5: AIzaSyCH7cdTRbJs7B0sgnvaf9iexOhDwzGhYTE 19304 - 24504
# key 6: AIzaSyAX5J4izCSxwwV5swhJl9knFanvxUHnMes 24505 - 29405
# key 7: AIzaSyCWfjW3u1IGBSG4oNQW5zTqFwMvi5-Lxuw 29406 - 34306
# key 8: AIzaSyDe0I1TU1BJVXK9QFiIBgehOQ-1imLGapg 34307 - 39207

def getKey(apiCount):
  if apiCount <= 4900:
    return "AIzaSyBMk7tRDPZYTBDwqvtzcF4E6ciQS-Rxtr8"
  elif apiCount <= 9801:
    return "AIzaSyARHge-NUDpfRYr2-gz1tqYGvgcUJhxm8c"
  elif apiCount <= 14702:
    return "AIzaSyDrCS-EG9LXEvraEaHfOSl2QrNJ51SrwcE"
  elif apiCount <= 19603:
    return "AIzaSyAsGZty7w_7cwXtky6YQrGlM-B3TOsRqJ4"
  elif apiCount <= 24504:
    return "AIzaSyCH7cdTRbJs7B0sgnvaf9iexOhDwzGhYTE"
  elif apiCount <= 29405:
    return "AIzaSyAX5J4izCSxwwV5swhJl9knFanvxUHnMes"
  elif apiCount <= 34306:
    return "AIzaSyCWfjW3u1IGBSG4oNQW5zTqFwMvi5-Lxuw"
  elif apiCount <= 39207:
    return "AIzaSyDe0I1TU1BJVXK9QFiIBgehOQ-1imLGapg"
  


df = pd.read_csv('youtube_dislike_dataset.csv', engine='python')

data = {}

# print(df)
apiCount = 0
itemCount = 0
for index, row in df.iterrows():
    apiKey = getKey(apiCount)
    video_id = row['video_id']
    channel_id = row['channel_id']
    video_title = row['title']
    view_count = row['view_count']
    likes = row['likes']
    dislikes = row['dislikes']
    comment_count = row['comment_count']
    tags = row['tags']
    published_at = row['published_at']
    channel_title = row['channel_title']


    print(video_id)
    url3 = "https://www.googleapis.com/youtube/v3/channels?part=statistics&id=" + channel_id + "&key=" + apiKey
    url = "https://www.googleapis.com/youtube/v3/commentThreads?key=" + apiKey + "&textFormat=plainText&part=snippet&videoId=" + video_id + "&maxResults=100"
    r = requests.get(url)
    json1 = r.json()
    r3 = requests.get(url3)
    json3 = r3.json()
    if ('items' in json1):
      num_subs = json3["items"][0]["statistics"]["subscriberCount"]
      comments = []
      for i in range(json1["pageInfo"]["totalResults"]):
        comment = json1["items"][i]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        comments.append(comment)
      model = {}
      model["comments"] = comments
      model["numSubscribers"] = num_subs
      model["channel_id"] = channel_id
      model["video_title"] = video_title
      model["view_count"] = view_count
      model["likes"] = likes
      model["dislikes"] = dislikes
      model["comment_count"] = comment_count
      model["tags"] = tags
      model["published_at"] = published_at
      model["channel_title"] = channel_title
      data[video_id] = model

    apiCount += 1
      
with open('youtubeData.txt', 'w', encoding='utf8') as file:
     file.write(json.dumps(data))





#print(df)
'''video_id = "--0bCF-iK2E"
channel_id = "UC6UL29enLNe4mqwTfAyeNuw"
url2 = "https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBMk7tRDPZYTBDwqvtzcF4E6ciQS-Rxtr8&textFormat=plainText&part=snippet&videoId=--0bCF-iK2E&maxResults=50"
url3 = "https://www.googleapis.com/youtube/v3/channels?part=statistics&id=" + channel_id + "&key=AIzaSyBMk7tRDPZYTBDwqvtzcF4E6ciQS-Rxtr8"


r = requests.get(url2)
json = r.json()

r3 = requests.get(url3)
json3 = r3.json()

num_subs = json3["items"][0]["statistics"]["subscriberCount"]

print(num_subs)

comments = []
for i in range(json["pageInfo"]["totalResults"]):
  comment = json["items"][i]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
  comments.append(comment)
print(comments)

model = {}
model["comments"] = comments

fileName = video_id + ".txt"
with open(fileName, 'w', encoding='utf8') as convert_file:
  convert_file.write(str(model))'''
# Out:
# Streaming output truncated to the last 5000 lines.
# i_oP0tkaw6k
# i_oUzreynW4
# i_wePORr_Rc
# ia8SbQvgx6k
# iaLny1DaVWs
# iaN4dMV1-mU
# iaTXw1YEpuU
# ib-g3ljHvHQ
# ibNM_UhAYPc
# ibi8qzG2wHI
# ibiE-TfzOro
# ibjtvile43Q
# ibobxUBQpow
# ibokjjcIm-I
# ibwixyj1Klc
# icIp39w27qs
# icObd1OHNgM
# icOv0xQMQyE
# icb2YowdpTQ
# icesjjvN6Sc
# icoOOiSlKK0
# icsFYKiUWuQ
# icwbkbYs3Lg
# icwlVorYc6U
# iczfPmQteeg
# idA-v0UbOlk
# idCV34yFwOQ
# idEAW3oiSnk
# idF_If7Juk8
# idp3zrmhjdo
# idsJcat2VbU
# idwgjfIvl3c
# ie4Cy0ySU1I
# ie6akURaz6E
# ie7hYxTrS8k
# ieAWbqNXvdA
# ieTnO1Dvt-I
# ieUV_BUwp80
# ieV9A1u1Bio
# ieaecUKoE1Y
# iebVtt5vw64
# iekpllwF0Jk
# iepXJTCKRRU
# if-CKQR91bw
# ifWftCEfavw
# if_2PTZKsEo
# ifhtR2aFjJk
# ifm8tpcO4vw
# ifqc0pWhvh4
# ifqqp7kH_tQ
# iftPjP5m8Xc
# ig1idOx6SrE
# ig8klBZd6lU
# ig9oHHWtlHo
# igJKC1gFBQk
# igOlNSCKPkQ
# igT8XYYhkmo
# igdvRUV_Oo8
# ighbZaLajbY
# igruKKchWrc
# igucCZ4jYvc
# ih06wdrh_04
# ih98_wn_b6I
# ihEEjwRlghQ
# ihMYnsipT5E
# ihPClrdFswg
# ihXcsdX28Cg
# ...

# %%
import pandas as pd

df = pd.read_csv('youtube_dislike_dataset.csv', engine='python')
